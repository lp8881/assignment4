# %%
# 安装缺失的 python 依赖并运行训练
# !python /content/drive/MyDrive/gaussian-splatting/train.py -s /content/drive/MyDrive/gaussian-splatting/chair --eval
# Out:
# 2026-05-30 14:07:27.250733: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Optimizing
# Output folder: ./output/7dc68038-2 [30/05 14:07:32]
# ------------LLFF HOLD------------- [30/05 14:07:32]
# Reading camera 100/100 [30/05 14:07:32]
# Loading Training Cameras [30/05 14:07:32]
# Loading Test Cameras [30/05 14:07:36]
# Number of points at initialisation :  13556 [30/05 14:07:36]
# Training progress:  23% 7000/30000 [03:25<15:29, 24.76it/s, Loss=0.0134593, Depth Loss=0.0000000]
# [ITER 7000] Evaluating test: L1 0.10317378147290304 PSNR 13.072724342346191 [30/05 14:11:05]
#
# [ITER 7000] Evaluating train: L1 0.0974821150302887 PSNR 13.57146224975586 [30/05 14:11:07]
#
# [ITER 7000] Saving Gaussians [30/05 14:11:07]
# ...

# %%
# !nvidia-smi
# Out:
# Mon Jun  1 03:54:01 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# 查看训练生成的模型文件
# !ls -R ./output
# Out:
# ls: cannot access './output': No such file or directory

# %%
# 使用训练生成的模型进行渲染
# !python /content/drive/MyDrive/gaussian-splatting/render.py -m /content/drive/MyDrive/gaussian-splatting/output/7dc68038-2
# Out:
# Looking for config file in /content/drive/MyDrive/gaussian-splatting/output/7dc68038-2/cfg_args
# Config file found: /content/drive/MyDrive/gaussian-splatting/output/7dc68038-2/cfg_args
# Rendering /content/drive/MyDrive/gaussian-splatting/output/7dc68038-2
# Loading trained model at iteration 30000 [30/05 14:56:04]
# ------------LLFF HOLD------------- [30/05 14:56:05]
# Reading camera 100/100 [30/05 14:56:05]
# Loading Training Cameras [30/05 14:56:05]
# Loading Test Cameras [30/05 14:56:08]
# Rendering progress: 100% 87/87 [00:20<00:00,  4.16it/s]
# Rendering progress: 100% 13/13 [00:02<00:00,  4.40it/s]

# %%
# HTTPS
# !git clone https://github.com/graphdeco-inria/gaussian-splatting --recursive
# Out:
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 1053, done.
# remote: Total 1053 (delta 0), reused 0 (delta 0), pack-reused 1053 (from 1)
# Receiving objects: 100% (1053/1053), 78.72 MiB | 23.91 MiB/s, done.
# Resolving deltas: 100% (592/592), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core.git) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization.git) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/fused-ssim' (https://github.com/rahul-goel/fused-ssim.git) registered for path 'submodules/fused-ssim'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# remote: Enumerating objects: 3293, done.
# remote: Counting objects: 100% (322/322), done.
# ...

# %%
# 安装必要的子模块依赖 (CUDA 算子)
# !pip install /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# !pip install /content/gaussian-splatting/submodules/simple-knn
# !pip install /content/gaussian-splatting/submodules/fused-ssim
# Out:
# Processing ./gaussian-splatting/submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization: filename=diff_gaussian_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3816626 sha256=fb1f453353136b431fdb7ac406caa6af7183907ad85001ee0473c444f81b2412
#   Stored in directory: /root/.cache/pip/wheels/01/e0/e8/f40a1cd6a1d5760cbd3036081bdad5b36c41fc11c786d4a404
# Successfully built diff_gaussian_rasterization
# ...
# Processing ./gaussian-splatting/submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for simple_knn: filename=simple_knn-0.0.0-cp312-cp312-linux_x86_64.whl size=3555546 sha256=a78fbb9c6db4e0f7cff92abcdaffc3011b427f8ecb6378a419f93836f7cad12d
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/1b/255828ebad94ea248378281b7926639d83ce4f394f0052800d
# Successfully built simple_knn
# ...
# Processing ./gaussian-splatting/submodules/fused-ssim
#   Preparing metadata (setup.py) ... done
# ...

# %%
# 计算模型的指标 (Metrics) - 移除不支持的 -s 参数
# 脚本会从模型目录下的 cfg_args 自动读取源数据路径
# !python /content/drive/MyDrive/gaussian-splatting/metrics.py \
    -m /content/drive/MyDrive/gaussian-splatting/output/7dc68038-2
# Out:
# Scene: /content/drive/MyDrive/gaussian-splatting/output/7dc68038-2
# Method: ours_30000
# Metric evaluation progress:   0% 0/13 [00:00<?, ?it/s]Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#
#   0% 0.00/528M [00:00<?, ?B/s]
#   3% 13.5M/528M [00:00<00:03, 141MB/s]
#   6% 31.6M/528M [00:00<00:03, 169MB/s]
#   9% 47.9M/528M [00:00<00:02, 169MB/s]
#  12% 64.1M/528M [00:00<00:02, 169MB/s]
#  16% 82.1M/528M [00:00<00:02, 176MB/s]
#  19% 99.0M/528M [00:00<00:02, 173MB/s]
#  22% 116M/528M [00:00<00:02, 163MB/s]
#  25% 132M/528M [00:00<00:02, 165MB/s]
#  29% 152M/528M [00:00<00:02, 179MB/s]
#  33% 172M/528M [00:01<00:01, 188MB/s]
#  37% 194M/528M [00:01<00:01, 201MB/s]
#  40% 214M/528M [00:01<00:01, 191MB/s]
#  44% 232M/528M [00:01<00:01, 191MB/s]
#  47% 250M/528M [00:01<00:01, 187MB/s]
#  51% 268M/528M [00:01<00:01, 187MB/s]
#  54% 287M/528M [00:01<00:01, 190MB/s]
#  58% 306M/528M [00:01<00:01, 186MB/s]
# ...

# %%
# !python /content/drive/MyDrive/gaussian-splatting/full_eval.py -s /content/drive/MyDrive/gaussian-splatting/chair --custom_model output/chair_task3 --custom_iterations 7000 30000
# Out:
# usage: full_eval.py [-h] [--skip_training] [--skip_rendering] [--skip_metrics]
#                     [--output_path OUTPUT_PATH] [--use_depth] [--use_expcomp]
#                     [--fast] [--aa] --mipnerf360 MIPNERF360 --tanksandtemples
#                     TANKSANDTEMPLES --deepblending DEEPBLENDING
# full_eval.py: error: the following arguments are required: --mipnerf360/-m360, --tanksandtemples/-tat, --deepblending/-db
